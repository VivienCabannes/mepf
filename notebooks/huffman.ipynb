# %% [markdown]
# # TODO
# - Implement dichotomic search, first build Huffman tree
# - Implement dicthomic search with limited depth
# - Check performance guarantee compared to empirical results

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import heapq
import logging

import matplotlib.pyplot as plt
import numpy as np

from entsearch import (
    Huffman_matrix,
    proba_generator,
    dichotomic_baseline,
)

# %%
m = 100
epsilon = 1
proba = proba_generator(m, epsilon)
cdf = proba.cumsum()

# %%
n = 1000
y_cat = np.sum(np.random.rand(n, 1) > cdf[np.newaxis, :], axis=1)
Y = np.zeros((n, m))
Y[np.arange(n), y_cat] = 1

# %%
T, mode, p_mode = dichotomic_baseline(Y)

# %%
plt.plot(T, p_mode)
plt.plot(T, np.max(proba) * np.ones(len(T)))
